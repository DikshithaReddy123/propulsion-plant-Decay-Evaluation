# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
pd.set_option('display.max_columns', None)

# %%
df=pd.read_csv('C:\\Users\\Mamidi Dikshitha\\Dropbox\\My PC (DESKTOP-3K30OSM)\\Downloads\\propulsion.csv')
df.head()
# Out:
#    Unnamed: 0  Lever position (lp) [ ]  Ship speed (v) [knots]  \
# 0           0                    9.300                    27.0
# 1           1                    6.175                    18.0
# 2           2                    3.144                     9.0
# 3           3                    3.144                     9.0
# 4           4                    6.175                    18.0
#
#    Gas Turbine shaft torque (GTT) [kN m]  \
# 0                              72762.205
# 1                              29760.552
# 2                               8375.774
# 3                               8377.589
# 4                              29761.091
#
#    Gas Turbine rate of revolutions (GTn) [rpm]  \
# 0                                     3560.393
# 1                                     2306.825
# 2                                     1386.739
# 3                                     1386.748
# 4                                     2306.825
#
#    Gas Generator rate of revolutions (GGn) [rpm]  \
# 0                                       9753.812
# 1                                       8780.012
# 2                                       7051.621
# 3                                       7098.469
# 4                                       8782.024
#
#    Starboard Propeller Torque (Ts) [kN]  Port Propeller Torque (Tp) [kN]  \
# 0                               644.806                          644.806
# 1                               246.011                          246.011
# 2                                60.318                           60.318
# 3                                60.339                           60.339
# 4                               246.021                          246.021
#
#    HP Turbine exit temperature (T48) [C]  \
# 0                               1086.583
# 1                                776.921
# 2                                589.764
# 3                                570.651
# 4                                769.855
#
#    GT Compressor inlet air temperature (T1) [C]  \
# 0                                         288.0
# 1                                         288.0
# 2                                         288.0
# 3                                         288.0
# 4                                         288.0
#
#    GT Compressor outlet air temperature (T2) [C]  \
# 0                                        780.304
# 1                                        665.511
# 2                                        580.587
# 3                                        576.565
# 4                                        663.682
#
#    HP Turbine exit pressure (P48) [bar]  \
# 0                                 4.523
# 1                                 2.518
# 2                                 1.392
# 3                                 1.390
# 4                                 2.518
#
#    GT Compressor inlet air pressure (P1) [bar]  \
# 0                                        0.998
# 1                                        0.998
# 2                                        0.998
# 3                                        0.998
# 4                                        0.998
#
#    GT Compressor outlet air pressure (P2) [bar]  \
# 0                                        22.879
# 1                                        13.438
# 2                                         7.566
# 3                                         7.409
# 4                                        13.374
#
#    Gas Turbine exhaust gas pressure (Pexh) [bar]  \
# 0                                          1.050
# 1                                          1.030
# 2                                          1.020
# 3                                          1.021
# 4                                          1.031
#
#    Turbine Injecton Control (TIC) [%]  Fuel flow (mf) [kg/s]  \
# 0                              90.435                  1.790
# 1                              34.596                  0.685
# 2                              12.477                  0.247
# 3                              11.678                  0.231
# 4                              34.154                  0.676
#
#    GT Compressor decay state coefficient.  GT Turbine decay state coefficient.
# 0                                   0.973                                0.978
# 1                                   0.995                                0.975
# 2                                   0.980                                0.978
# 3                                   0.984                                1.000
# 4                                   0.998                                0.980

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0  Lever position (lp) [ ]  Ship speed (v) [knots]  \
# count  10000.00000             10000.000000            10000.000000
# mean    4999.50000                 5.150075               14.951400
# std     2886.89568                 2.624015                7.740467
# min        0.00000                 1.138000                3.000000
# 25%     2499.75000                 3.144000                9.000000
# 50%     4999.50000                 5.140000               15.000000
# 75%     7499.25000                 7.148000               21.000000
# max     9999.00000                 9.300000               27.000000
#
#        Gas Turbine shaft torque (GTT) [kN m]  \
# count                           10000.000000
# mean                            27100.647714
# std                             22062.780307
# min                               253.547000
# 25%                              8375.791500
# 50%                             21630.133500
# 75%                             39000.710250
# max                             72783.338000
#
#        Gas Turbine rate of revolutions (GTn) [rpm]  \
# count                                 10000.000000
# mean                                   2131.151788
# std                                     772.211732
# min                                    1307.675000
# 25%                                    1386.758000
# 50%                                    1924.325000
# 75%                                    2678.078000
# max                                    3560.741000
#
#        Gas Generator rate of revolutions (GGn) [rpm]  \
# count                                   10000.000000
# mean                                     8194.182366
# std                                      1090.569425
# min                                      6589.002000
# 25%                                      7056.520500
# 50%                                      8480.527000
# 75%                                      9132.132500
# max                                      9797.103000
#
#        Starboard Propeller Torque (Ts) [kN]  Port Propeller Torque (Tp) [kN]  \
# count                          10000.000000                     10000.000000
# mean                             225.957785                       225.957785
# std                              199.737886                       199.737886
# min                                5.304000                         5.304000
# 25%                               60.317000                        60.317000
# 50%                              175.264000                       175.264000
# 75%                              332.360000                       332.360000
# max                              645.249000                       645.249000
#
#        HP Turbine exit temperature (T48) [C]  \
# count                           10000.000000
# mean                              734.476178
# std                               173.009157
# min                               444.731000
# 25%                               589.841000
# 50%                               705.351000
# 75%                               833.154750
# max                              1115.797000
#
#        GT Compressor inlet air temperature (T1) [C]  \
# count                                       10000.0
# mean                                          288.0
# std                                             0.0
# min                                           288.0
# 25%                                           288.0
# 50%                                           288.0
# 75%                                           288.0
# max                                           288.0
#
#        GT Compressor outlet air temperature (T2) [C]  \
# count                                   10000.000000
# mean                                      645.748980
# std                                        72.483036
# min                                       540.999000
# 25%                                       577.980750
# 50%                                       636.800000
# 75%                                       693.656750
# max                                       789.094000
#
#        HP Turbine exit pressure (P48) [bar]  \
# count                          10000.000000
# mean                               2.345732
# std                                1.081038
# min                                1.093000
# 25%                                1.389000
# 50%                                2.082000
# 75%                                2.981000
# max                                4.560000
#
#        GT Compressor inlet air pressure (P1) [bar]  \
# count                                 1.000000e+04
# mean                                  9.980000e-01
# std                                   2.236101e-13
# min                                   9.980000e-01
# 25%                                   9.980000e-01
# 50%                                   9.980000e-01
# 75%                                   9.980000e-01
# max                                   9.980000e-01
#
#        GT Compressor outlet air pressure (P2) [bar]  \
# count                                  10000.000000
# mean                                      12.262597
# std                                        5.320817
# min                                        5.828000
# 25%                                        7.445000
# 50%                                       11.086000
# 75%                                       15.649000
# max                                       23.140000
#
#        Gas Turbine exhaust gas pressure (Pexh) [bar]  \
# count                                   10000.000000
# mean                                        1.029402
# std                                         0.010353
# min                                         1.019000
# 25%                                         1.020000
# 50%                                         1.026000
# 75%                                         1.036000
# max                                         1.052000
#
#        Turbine Injecton Control (TIC) [%]  Fuel flow (mf) [kg/s]  \
# count                        10000.000000           10000.000000
# mean                            33.480715               0.659100
# std                             25.721725               0.504791
# min                              0.000000               0.068000
# 25%                             13.534000               0.246000
# 50%                             25.249500               0.496000
# 75%                             44.500000               0.881000
# max                             92.556000               1.832000
#
#        GT Compressor decay state coefficient.  \
# count                            10000.000000
# mean                                 0.975021
# std                                  0.014734
# min                                  0.950000
# 25%                                  0.962000
# 50%                                  0.975000
# 75%                                  0.988000
# max                                  1.000000
#
#        GT Turbine decay state coefficient.
# count                         10000.000000
# mean                              0.987455
# std                               0.007510
# min                               0.975000
# 25%                               0.981000
# 50%                               0.987000
# 75%                               0.994000
# max                               1.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                       0
# Lever position (lp) [ ]                          0
# Ship speed (v) [knots]                           0
# Gas Turbine shaft torque (GTT) [kN m]            0
# Gas Turbine rate of revolutions (GTn) [rpm]      0
# Gas Generator rate of revolutions (GGn) [rpm]    0
# Starboard Propeller Torque (Ts) [kN]             0
# Port Propeller Torque (Tp) [kN]                  0
# HP Turbine exit temperature (T48) [C]            0
# GT Compressor inlet air temperature (T1) [C]     0
# GT Compressor outlet air temperature (T2) [C]    0
# HP Turbine exit pressure (P48) [bar]             0
# GT Compressor inlet air pressure (P1) [bar]      0
# GT Compressor outlet air pressure (P2) [bar]     0
# Gas Turbine exhaust gas pressure (Pexh) [bar]    0
# Turbine Injecton Control (TIC) [%]               0
# Fuel flow (mf) [kg/s]                            0
# GT Compressor decay state coefficient.           0
# GT Turbine decay state coefficient.              0
# dtype: int64

# %%
df.astype(int)
# Out:
#       Unnamed: 0  Lever position (lp) [ ]  Ship speed (v) [knots]  \
# 0              0                        9                      27
# 1              1                        6                      18
# 2              2                        3                       9
# 3              3                        3                       9
# 4              4                        6                      18
# ...          ...                      ...                     ...
# 9995        9995                        2                       6
# 9996        9996                        5                      15
# 9997        9997                        8                      24
# 9998        9998                        6                      18
# 9999        9999                        8                      24
#
#       Gas Turbine shaft torque (GTT) [kN m]  \
# 0                                     72762
# 1                                     29760
# 2                                      8375
# 3                                      8377
# 4                                     29761
# ...                                     ...
# 9995                                   5858
# 9996                                  21633
# 9997                                  50994
# 9998                                  29761
# 9999                                  50990
#
#       Gas Turbine rate of revolutions (GTn) [rpm]  \
# 0                                            3560
# 1                                            2306
# 2                                            1386
# 3                                            1386
# 4                                            2306
# ...                                           ...
# 9995                                         1349
# 9996                                         1924
# 9997                                         3087
# 9998                                         2306
# 9999                                         3087
#
#       Gas Generator rate of revolutions (GGn) [rpm]  \
# 0                                              9753
# 1                                              8780
# 2                                              7051
# 3                                              7098
# 4                                              8782
# ...                                             ...
# 9995                                           6736
# 9996                                           8497
# 9997                                           9324
# 9998                                           8793
# 9999                                           9300
#
#       Starboard Propeller Torque (Ts) [kN]  Port Propeller Torque (Tp) [kN]  \
# 0                                      644                              644
# 1                                      246                              246
# 2                                       60                               60
# 3                                       60                               60
# 4                                      246                              246
# ...                                    ...                              ...
# 9995                                    23                               23
# 9996                                   175                              175
# 9997                                   438                              438
# 9998                                   245                              245
# 9999                                   438                              438
#
#       HP Turbine exit temperature (T48) [C]  \
# 0                                      1086
# 1                                       776
# 2                                       589
# 3                                       570
# 4                                       769
# ...                                     ...
# 9995                                    581
# 9996                                    696
# 9997                                    928
# 9998                                    783
# 9999                                    929
#
#       GT Compressor inlet air temperature (T1) [C]  \
# 0                                              288
# 1                                              288
# 2                                              288
# 3                                              288
# 4                                              288
# ...                                            ...
# 9995                                           288
# 9996                                           288
# 9997                                           288
# 9998                                           288
# 9999                                           288
#
#       GT Compressor outlet air temperature (T2) [C]  \
# 0                                               780
# 1                                               665
# 2                                               580
# 3                                               576
# 4                                               663
# ...                                             ...
# 9995                                            564
# 9996                                            635
# 9997                                            737
# 9998                                            668
# 9999                                            731
#
#       HP Turbine exit pressure (P48) [bar]  \
# 0                                        4
# 1                                        2
# 2                                        1
# 3                                        1
# 4                                        2
# ...                                    ...
# 9995                                     1
# 9996                                     2
# 9997                                     3
# 9998                                     2
# 9999                                     3
#
#       GT Compressor inlet air pressure (P1) [bar]  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 9995                                            0
# 9996                                            0
# 9997                                            0
# 9998                                            0
# 9999                                            0
#
#       GT Compressor outlet air pressure (P2) [bar]  \
# 0                                               22
# 1                                               13
# 2                                                7
# 3                                                7
# 4                                               13
# ...                                            ...
# 9995                                             6
# 9996                                            10
# 9997                                            18
# 9998                                            13
# 9999                                            18
#
#       Gas Turbine exhaust gas pressure (Pexh) [bar]  \
# 0                                                 1
# 1                                                 1
# 2                                                 1
# 3                                                 1
# 4                                                 1
# ...                                             ...
# 9995                                              1
# 9996                                              1
# 9997                                              1
# 9998                                              1
# 9999                                              1
#
#       Turbine Injecton Control (TIC) [%]  Fuel flow (mf) [kg/s]  \
# 0                                     90                      1
# 1                                     34                      0
# 2                                     12                      0
# 3                                     11                      0
# 4                                     34                      0
# ...                                  ...                    ...
# 9995                                  21                      0
# 9996                                  24                      0
# 9997                                  60                      1
# 9998                                  34                      0
# 9999                                  61                      1
#
#       GT Compressor decay state coefficient.  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ...                                      ...
# 9995                                       0
# 9996                                       0
# 9997                                       0
# 9998                                       0
# 9999                                       0
#
#       GT Turbine decay state coefficient.
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       1
# 4                                       0
# ...                                   ...
# 9995                                    0
# 9996                                    1
# 9997                                    0
# 9998                                    0
# 9999                                    0
#
# [10000 rows x 19 columns]

# %%
df.shape
# Out:
# (10000, 19)

# %%
df.corr()
# Out:
#                                                Unnamed: 0  \
# Unnamed: 0                                       1.000000
# Lever position (lp) [ ]                          0.002340
# Ship speed (v) [knots]                           0.002237
# Gas Turbine shaft torque (GTT) [kN m]            0.006241
# Gas Turbine rate of revolutions (GTn) [rpm]      0.006338
# Gas Generator rate of revolutions (GGn) [rpm]    0.002081
# Starboard Propeller Torque (Ts) [kN]             0.005816
# Port Propeller Torque (Tp) [kN]                  0.005816
# HP Turbine exit temperature (T48) [C]            0.006907
# GT Compressor inlet air temperature (T1) [C]          NaN
# GT Compressor outlet air temperature (T2) [C]    0.005475
# HP Turbine exit pressure (P48) [bar]             0.006299
# GT Compressor inlet air pressure (P1) [bar]      0.000000
# GT Compressor outlet air pressure (P2) [bar]     0.005952
# Gas Turbine exhaust gas pressure (Pexh) [bar]    0.006920
# Turbine Injecton Control (TIC) [%]               0.007610
# Fuel flow (mf) [kg/s]                            0.007342
# GT Compressor decay state coefficient.          -0.001494
# GT Turbine decay state coefficient.              0.004072
#
#                                                Lever position (lp) [ ]  \
# Unnamed: 0                                                2.339718e-03
# Lever position (lp) [ ]                                   1.000000e+00
# Ship speed (v) [knots]                                    9.999152e-01
# Gas Turbine shaft torque (GTT) [kN m]                     9.609108e-01
# Gas Turbine rate of revolutions (GTn) [rpm]               9.617251e-01
# Gas Generator rate of revolutions (GGn) [rpm]             9.860548e-01
# Starboard Propeller Torque (Ts) [kN]                      9.592392e-01
# Port Propeller Torque (Tp) [kN]                           9.592392e-01
# HP Turbine exit temperature (T48) [C]                     9.607490e-01
# GT Compressor inlet air temperature (T1) [C]                       NaN
# GT Compressor outlet air temperature (T2) [C]             9.825756e-01
# HP Turbine exit pressure (P48) [bar]                      9.628748e-01
# GT Compressor inlet air pressure (P1) [bar]              -4.781148e-14
# GT Compressor outlet air pressure (P2) [bar]              9.689234e-01
# Gas Turbine exhaust gas pressure (Pexh) [bar]             9.531825e-01
# Turbine Injecton Control (TIC) [%]                        9.126123e-01
# Fuel flow (mf) [kg/s]                                     9.310163e-01
# GT Compressor decay state coefficient.                   -2.069951e-03
# GT Turbine decay state coefficient.                      -1.044850e-03
#
#                                                Ship speed (v) [knots]  \
# Unnamed: 0                                               2.236860e-03
# Lever position (lp) [ ]                                  9.999152e-01
# Ship speed (v) [knots]                                   1.000000e+00
# Gas Turbine shaft torque (GTT) [kN m]                    9.581356e-01
# Gas Turbine rate of revolutions (GTn) [rpm]              9.600550e-01
# Gas Generator rate of revolutions (GGn) [rpm]            9.866515e-01
# Starboard Propeller Torque (Ts) [kN]                     9.563791e-01
# Port Propeller Torque (Tp) [kN]                          9.563791e-01
# HP Turbine exit temperature (T48) [C]                    9.583419e-01
# GT Compressor inlet air temperature (T1) [C]                      NaN
# GT Compressor outlet air temperature (T2) [C]            9.809851e-01
# HP Turbine exit pressure (P48) [bar]                     9.604373e-01
# GT Compressor inlet air pressure (P1) [bar]              4.850010e-16
# GT Compressor outlet air pressure (P2) [bar]             9.667917e-01
# Gas Turbine exhaust gas pressure (Pexh) [bar]            9.506467e-01
# Turbine Injecton Control (TIC) [%]                       9.089850e-01
# Fuel flow (mf) [kg/s]                                    9.274125e-01
# GT Compressor decay state coefficient.                  -2.008915e-03
# GT Turbine decay state coefficient.                     -1.008008e-03
#
#                                                Gas Turbine shaft torque (GTT) [kN m]  \
# Unnamed: 0                                                              6.240895e-03
# Lever position (lp) [ ]                                                 9.609108e-01
# Ship speed (v) [knots]                                                  9.581356e-01
# Gas Turbine shaft torque (GTT) [kN m]                                   1.000000e+00
# Gas Turbine rate of revolutions (GTn) [rpm]                             9.896635e-01
# Gas Generator rate of revolutions (GGn) [rpm]                           9.331650e-01
# Starboard Propeller Torque (Ts) [kN]                                    9.991697e-01
# Port Propeller Torque (Tp) [kN]                                         9.991697e-01
# HP Turbine exit temperature (T48) [C]                                   9.910936e-01
# GT Compressor inlet air temperature (T1) [C]                                     NaN
# GT Compressor outlet air temperature (T2) [C]                           9.902912e-01
# HP Turbine exit pressure (P48) [bar]                                    9.988876e-01
# GT Compressor inlet air pressure (P1) [bar]                            -1.268564e-15
# GT Compressor outlet air pressure (P2) [bar]                            9.975738e-01
# Gas Turbine exhaust gas pressure (Pexh) [bar]                           9.960142e-01
# Turbine Injecton Control (TIC) [%]                                      9.774239e-01
# Fuel flow (mf) [kg/s]                                                   9.950145e-01
# GT Compressor decay state coefficient.                                  7.359966e-04
# GT Turbine decay state coefficient.                                    -5.327690e-04
#
#                                                Gas Turbine rate of revolutions (GTn) [rpm]  \
# Unnamed: 0                                                                    6.337764e-03
# Lever position (lp) [ ]                                                       9.617251e-01
# Ship speed (v) [knots]                                                        9.600550e-01
# Gas Turbine shaft torque (GTT) [kN m]                                         9.896635e-01
# Gas Turbine rate of revolutions (GTn) [rpm]                                   1.000000e+00
# Gas Generator rate of revolutions (GGn) [rpm]                                 9.429442e-01
# Starboard Propeller Torque (Ts) [kN]                                          9.885716e-01
# Port Propeller Torque (Tp) [kN]                                               9.885716e-01
# HP Turbine exit temperature (T48) [C]                                         9.794189e-01
# GT Compressor inlet air temperature (T1) [C]                                           NaN
# GT Compressor outlet air temperature (T2) [C]                                 9.891571e-01
# HP Turbine exit pressure (P48) [bar]                                          9.950861e-01
# GT Compressor inlet air pressure (P1) [bar]                                   7.448827e-15
# GT Compressor outlet air pressure (P2) [bar]                                  9.960080e-01
# Gas Turbine exhaust gas pressure (Pexh) [bar]                                 9.940473e-01
# Turbine Injecton Control (TIC) [%]                                            9.618757e-01
# Fuel flow (mf) [kg/s]                                                         9.801137e-01
# GT Compressor decay state coefficient.                                        1.557782e-04
# GT Turbine decay state coefficient.                                          -6.767443e-04
#
#                                                Gas Generator rate of revolutions (GGn) [rpm]  \
# Unnamed: 0                                                                      2.080657e-03
# Lever position (lp) [ ]                                                         9.860548e-01
# Ship speed (v) [knots]                                                          9.866515e-01
# Gas Turbine shaft torque (GTT) [kN m]                                           9.331650e-01
# Gas Turbine rate of revolutions (GTn) [rpm]                                     9.429442e-01
# Gas Generator rate of revolutions (GGn) [rpm]                                   1.000000e+00
# Starboard Propeller Torque (Ts) [kN]                                            9.298881e-01
# Port Propeller Torque (Tp) [kN]                                                 9.298881e-01
# HP Turbine exit temperature (T48) [C]                                           9.395067e-01
# GT Compressor inlet air temperature (T1) [C]                                             NaN
# GT Compressor outlet air temperature (T2) [C]                                   9.666655e-01
# HP Turbine exit pressure (P48) [bar]                                            9.375635e-01
# GT Compressor inlet air pressure (P1) [bar]                                     1.291590e-15
# GT Compressor outlet air pressure (P2) [bar]                                    9.460192e-01
# Gas Turbine exhaust gas pressure (Pexh) [bar]                                   9.243745e-01
# Turbine Injecton Control (TIC) [%]                                              8.785516e-01
# Fuel flow (mf) [kg/s]                                                           8.968861e-01
# GT Compressor decay state coefficient.                                         -2.085154e-02
# GT Turbine decay state coefficient.                                             8.703413e-03
#
#                                                Starboard Propeller Torque (Ts) [kN]  \
# Unnamed: 0                                                             5.815779e-03
# Lever position (lp) [ ]                                                9.592392e-01
# Ship speed (v) [knots]                                                 9.563791e-01
# Gas Turbine shaft torque (GTT) [kN m]                                  9.991697e-01
# Gas Turbine rate of revolutions (GTn) [rpm]                            9.885716e-01
# Gas Generator rate of revolutions (GGn) [rpm]                          9.298881e-01
# Starboard Propeller Torque (Ts) [kN]                                   1.000000e+00
# Port Propeller Torque (Tp) [kN]                                        1.000000e+00
# HP Turbine exit temperature (T48) [C]                                  9.858946e-01
# GT Compressor inlet air temperature (T1) [C]                                    NaN
# GT Compressor outlet air temperature (T2) [C]                          9.874675e-01
# HP Turbine exit pressure (P48) [bar]                                   9.979956e-01
# GT Compressor inlet air pressure (P1) [bar]                           -1.725008e-15
# GT Compressor outlet air pressure (P2) [bar]                           9.961646e-01
# Gas Turbine exhaust gas pressure (Pexh) [bar]                          9.961904e-01
# Turbine Injecton Control (TIC) [%]                                     9.769639e-01
# Fuel flow (mf) [kg/s]                                                  9.942538e-01
# GT Compressor decay state coefficient.                                -1.594073e-03
# GT Turbine decay state coefficient.                                   -6.686727e-04
#
#                                                Port Propeller Torque (Tp) [kN]  \
# Unnamed: 0                                                        5.815779e-03
# Lever position (lp) [ ]                                           9.592392e-01
# Ship speed (v) [knots]                                            9.563791e-01
# Gas Turbine shaft torque (GTT) [kN m]                             9.991697e-01
# Gas Turbine rate of revolutions (GTn) [rpm]                       9.885716e-01
# Gas Generator rate of revolutions (GGn) [rpm]                     9.298881e-01
# Starboard Propeller Torque (Ts) [kN]                              1.000000e+00
# Port Propeller Torque (Tp) [kN]                                   1.000000e+00
# HP Turbine exit temperature (T48) [C]                             9.858946e-01
# GT Compressor inlet air temperature (T1) [C]                               NaN
# GT Compressor outlet air temperature (T2) [C]                     9.874675e-01
# HP Turbine exit pressure (P48) [bar]                              9.979956e-01
# GT Compressor inlet air pressure (P1) [bar]                      -1.725008e-15
# GT Compressor outlet air pressure (P2) [bar]                      9.961646e-01
# Gas Turbine exhaust gas pressure (Pexh) [bar]                     9.961904e-01
# Turbine Injecton Control (TIC) [%]                                9.769639e-01
# Fuel flow (mf) [kg/s]                                             9.942538e-01
# GT Compressor decay state coefficient.                           -1.594073e-03
# GT Turbine decay state coefficient.                              -6.686727e-04
#
#                                                HP Turbine exit temperature (T48) [C]  \
# Unnamed: 0                                                              6.906972e-03
# Lever position (lp) [ ]                                                 9.607490e-01
# Ship speed (v) [knots]                                                  9.583419e-01
# Gas Turbine shaft torque (GTT) [kN m]                                   9.910936e-01
# Gas Turbine rate of revolutions (GTn) [rpm]                             9.794189e-01
# Gas Generator rate of revolutions (GGn) [rpm]                           9.395067e-01
# Starboard Propeller Torque (Ts) [kN]                                    9.858946e-01
# Port Propeller Torque (Tp) [kN]                                         9.858946e-01
# HP Turbine exit temperature (T48) [C]                                   1.000000e+00
# GT Compressor inlet air temperature (T1) [C]                                     NaN
# GT Compressor outlet air temperature (T2) [C]                           9.922114e-01
# HP Turbine exit pressure (P48) [bar]                                    9.892993e-01
# GT Compressor inlet air pressure (P1) [bar]                            -1.043977e-15
# GT Compressor outlet air pressure (P2) [bar]                            9.903642e-01
# Gas Turbine exhaust gas pressure (Pexh) [bar]                           9.799853e-01
# Turbine Injecton Control (TIC) [%]                                      9.692904e-01
# Fuel flow (mf) [kg/s]                                                   9.863241e-01
# GT Compressor decay state coefficient.                                 -4.171919e-02
# GT Turbine decay state coefficient.                                    -3.990061e-02
#
#                                                GT Compressor inlet air temperature (T1) [C]  \
# Unnamed: 0                                                                              NaN
# Lever position (lp) [ ]                                                                 NaN
# Ship speed (v) [knots]                                                                  NaN
# Gas Turbine shaft torque (GTT) [kN m]                                                   NaN
# Gas Turbine rate of revolutions (GTn) [rpm]                                             NaN
# Gas Generator rate of revolutions (GGn) [rpm]                                           NaN
# Starboard Propeller Torque (Ts) [kN]                                                    NaN
# Port Propeller Torque (Tp) [kN]                                                         NaN
# HP Turbine exit temperature (T48) [C]                                                   NaN
# GT Compressor inlet air temperature (T1) [C]                                            NaN
# GT Compressor outlet air temperature (T2) [C]                                           NaN
# HP Turbine exit pressure (P48) [bar]                                                    NaN
# GT Compressor inlet air pressure (P1) [bar]                                             NaN
# GT Compressor outlet air pressure (P2) [bar]                                            NaN
# Gas Turbine exhaust gas pressure (Pexh) [bar]                                           NaN
# Turbine Injecton Control (TIC) [%]                                                      NaN
# Fuel flow (mf) [kg/s]                                                                   NaN
# GT Compressor decay state coefficient.                                                  NaN
# GT Turbine decay state coefficient.                                                     NaN
#
#                                                GT Compressor outlet air temperature (T2) [C]  \
# Unnamed: 0                                                                      5.475328e-03
# Lever position (lp) [ ]                                                         9.825756e-01
# Ship speed (v) [knots]                                                          9.809851e-01
# Gas Turbine shaft torque (GTT) [kN m]                                           9.902912e-01
# Gas Turbine rate of revolutions (GTn) [rpm]                                     9.891571e-01
# Gas Generator rate of revolutions (GGn) [rpm]                                   9.666655e-01
# Starboard Propeller Torque (Ts) [kN]                                            9.874675e-01
# Port Propeller Torque (Tp) [kN]                                                 9.874675e-01
# HP Turbine exit temperature (T48) [C]                                           9.922114e-01
# GT Compressor inlet air temperature (T1) [C]                                             NaN
# GT Compressor outlet air temperature (T2) [C]                                   1.000000e+00
# HP Turbine exit pressure (P48) [bar]                                            9.917257e-01
# GT Compressor inlet air pressure (P1) [bar]                                     1.024804e-14
# GT Compressor outlet air pressure (P2) [bar]                                    9.943809e-01
# Gas Turbine exhaust gas pressure (Pexh) [bar]                                   9.834892e-01
# Turbine Injecton Control (TIC) [%]                                              9.582445e-01
# Fuel flow (mf) [kg/s]                                                           9.764256e-01
# GT Compressor decay state coefficient.                                         -4.909594e-02
# GT Turbine decay state coefficient.                                            -1.806027e-02
#
#                                                HP Turbine exit pressure (P48) [bar]  \
# Unnamed: 0                                                             6.298626e-03
# Lever position (lp) [ ]                                                9.628748e-01
# Ship speed (v) [knots]                                                 9.604373e-01
# Gas Turbine shaft torque (GTT) [kN m]                                  9.988876e-01
# Gas Turbine rate of revolutions (GTn) [rpm]                            9.950861e-01
# Gas Generator rate of revolutions (GGn) [rpm]                          9.375635e-01
# Starboard Propeller Torque (Ts) [kN]                                   9.979956e-01
# Port Propeller Torque (Tp) [kN]                                        9.979956e-01
# HP Turbine exit temperature (T48) [C]                                  9.892993e-01
# GT Compressor inlet air temperature (T1) [C]                                    NaN
# GT Compressor outlet air temperature (T2) [C]                          9.917257e-01
# HP Turbine exit pressure (P48) [bar]                                   1.000000e+00
# GT Compressor inlet air pressure (P1) [bar]                            2.583553e-14
# GT Compressor outlet air pressure (P2) [bar]                           9.994014e-01
# Gas Turbine exhaust gas pressure (Pexh) [bar]                          9.979414e-01
# Turbine Injecton Control (TIC) [%]                                     9.752680e-01
# Fuel flow (mf) [kg/s]                                                  9.926555e-01
# GT Compressor decay state coefficient.                                 6.266350e-03
# GT Turbine decay state coefficient.                                   -3.527565e-03
#
#                                                GT Compressor inlet air pressure (P1) [bar]  \
# Unnamed: 0                                                                    0.000000e+00
# Lever position (lp) [ ]                                                      -4.781148e-14
# Ship speed (v) [knots]                                                        4.850010e-16
# Gas Turbine shaft torque (GTT) [kN m]                                        -1.268564e-15
# Gas Turbine rate of revolutions (GTn) [rpm]                                   7.448827e-15
# Gas Generator rate of revolutions (GGn) [rpm]                                 1.291590e-15
# Starboard Propeller Torque (Ts) [kN]                                         -1.725008e-15
# Port Propeller Torque (Tp) [kN]                                              -1.725008e-15
# HP Turbine exit temperature (T48) [C]                                        -1.043977e-15
# GT Compressor inlet air temperature (T1) [C]                                           NaN
# GT Compressor outlet air temperature (T2) [C]                                 1.024804e-14
# HP Turbine exit pressure (P48) [bar]                                          2.583553e-14
# GT Compressor inlet air pressure (P1) [bar]                                   1.000000e+00
# GT Compressor outlet air pressure (P2) [bar]                                 -1.614254e-15
# Gas Turbine exhaust gas pressure (Pexh) [bar]                                -5.395954e-12
# Turbine Injecton Control (TIC) [%]                                           -3.352792e-15
# Fuel flow (mf) [kg/s]                                                        -4.014231e-15
# GT Compressor decay state coefficient.                                        8.732834e-13
# GT Turbine decay state coefficient.                                           2.074981e-12
#
#                                                GT Compressor outlet air pressure (P2) [bar]  \
# Unnamed: 0                                                                     5.952156e-03
# Lever position (lp) [ ]                                                        9.689234e-01
# Ship speed (v) [knots]                                                         9.667917e-01
# Gas Turbine shaft torque (GTT) [kN m]                                          9.975738e-01
# Gas Turbine rate of revolutions (GTn) [rpm]                                    9.960080e-01
# Gas Generator rate of revolutions (GGn) [rpm]                                  9.460192e-01
# Starboard Propeller Torque (Ts) [kN]                                           9.961646e-01
# Port Propeller Torque (Tp) [kN]                                                9.961646e-01
# HP Turbine exit temperature (T48) [C]                                          9.903642e-01
# GT Compressor inlet air temperature (T1) [C]                                            NaN
# GT Compressor outlet air temperature (T2) [C]                                  9.943809e-01
# HP Turbine exit pressure (P48) [bar]                                           9.994014e-01
# GT Compressor inlet air pressure (P1) [bar]                                   -1.614254e-15
# GT Compressor outlet air pressure (P2) [bar]                                   1.000000e+00
# Gas Turbine exhaust gas pressure (Pexh) [bar]                                  9.963431e-01
# Turbine Injecton Control (TIC) [%]                                             9.716515e-01
# Fuel flow (mf) [kg/s]                                                          9.891797e-01
# GT Compressor decay state coefficient.                                         6.488394e-03
# GT Turbine decay state coefficient.                                           -1.917078e-02
#
#                                                Gas Turbine exhaust gas pressure (Pexh) [bar]  \
# Unnamed: 0                                                                      6.919724e-03
# Lever position (lp) [ ]                                                         9.531825e-01
# Ship speed (v) [knots]                                                          9.506467e-01
# Gas Turbine shaft torque (GTT) [kN m]                                           9.960142e-01
# Gas Turbine rate of revolutions (GTn) [rpm]                                     9.940473e-01
# Gas Generator rate of revolutions (GGn) [rpm]                                   9.243745e-01
# Starboard Propeller Torque (Ts) [kN]                                            9.961904e-01
# Port Propeller Torque (Tp) [kN]                                                 9.961904e-01
# HP Turbine exit temperature (T48) [C]                                           9.799853e-01
# GT Compressor inlet air temperature (T1) [C]                                             NaN
# GT Compressor outlet air temperature (T2) [C]                                   9.834892e-01
# HP Turbine exit pressure (P48) [bar]                                            9.979414e-01
# GT Compressor inlet air pressure (P1) [bar]                                    -5.395954e-12
# GT Compressor outlet air pressure (P2) [bar]                                    9.963431e-01
# Gas Turbine exhaust gas pressure (Pexh) [bar]                                   1.000000e+00
# Turbine Injecton Control (TIC) [%]                                              9.737792e-01
# Fuel flow (mf) [kg/s]                                                           9.908946e-01
# GT Compressor decay state coefficient.                                          3.339688e-02
# GT Turbine decay state coefficient.                                             1.126419e-02
#
#                                                Turbine Injecton Control (TIC) [%]  \
# Unnamed: 0                                                           7.610257e-03
# Lever position (lp) [ ]                                              9.126123e-01
# Ship speed (v) [knots]                                               9.089850e-01
# Gas Turbine shaft torque (GTT) [kN m]                                9.774239e-01
# Gas Turbine rate of revolutions (GTn) [rpm]                          9.618757e-01
# Gas Generator rate of revolutions (GGn) [rpm]                        8.785516e-01
# Starboard Propeller Torque (Ts) [kN]                                 9.769639e-01
# Port Propeller Torque (Tp) [kN]                                      9.769639e-01
# HP Turbine exit temperature (T48) [C]                                9.692904e-01
# GT Compressor inlet air temperature (T1) [C]                                  NaN
# GT Compressor outlet air temperature (T2) [C]                        9.582445e-01
# HP Turbine exit pressure (P48) [bar]                                 9.752680e-01
# GT Compressor inlet air pressure (P1) [bar]                         -3.352792e-15
# GT Compressor outlet air pressure (P2) [bar]                         9.716515e-01
# Gas Turbine exhaust gas pressure (Pexh) [bar]                        9.737792e-01
# Turbine Injecton Control (TIC) [%]                                   1.000000e+00
# Fuel flow (mf) [kg/s]                                                9.852611e-01
# GT Compressor decay state coefficient.                              -3.414874e-02
# GT Turbine decay state coefficient.                                 -1.916872e-02
#
#                                                Fuel flow (mf) [kg/s]  \
# Unnamed: 0                                              7.342448e-03
# Lever position (lp) [ ]                                 9.310163e-01
# Ship speed (v) [knots]                                  9.274125e-01
# Gas Turbine shaft torque (GTT) [kN m]                   9.950145e-01
# Gas Turbine rate of revolutions (GTn) [rpm]             9.801137e-01
# Gas Generator rate of revolutions (GGn) [rpm]           8.968861e-01
# Starboard Propeller Torque (Ts) [kN]                    9.942538e-01
# Port Propeller Torque (Tp) [kN]                         9.942538e-01
# HP Turbine exit temperature (T48) [C]                   9.863241e-01
# GT Compressor inlet air temperature (T1) [C]                     NaN
# GT Compressor outlet air temperature (T2) [C]           9.764256e-01
# HP Turbine exit pressure (P48) [bar]                    9.926555e-01
# GT Compressor inlet air pressure (P1) [bar]            -4.014231e-15
# GT Compressor outlet air pressure (P2) [bar]            9.891797e-01
# Gas Turbine exhaust gas pressure (Pexh) [bar]           9.908946e-01
# Turbine Injecton Control (TIC) [%]                      9.852611e-01
# Fuel flow (mf) [kg/s]                                   1.000000e+00
# GT Compressor decay state coefficient.                 -1.583545e-02
# GT Turbine decay state coefficient.                    -1.816774e-02
#
#                                                GT Compressor decay state coefficient.  \
# Unnamed: 0                                                              -1.493864e-03
# Lever position (lp) [ ]                                                 -2.069951e-03
# Ship speed (v) [knots]                                                  -2.008915e-03
# Gas Turbine shaft torque (GTT) [kN m]                                    7.359966e-04
# Gas Turbine rate of revolutions (GTn) [rpm]                              1.557782e-04
# Gas Generator rate of revolutions (GGn) [rpm]                           -2.085154e-02
# Starboard Propeller Torque (Ts) [kN]                                    -1.594073e-03
# Port Propeller Torque (Tp) [kN]                                         -1.594073e-03
# HP Turbine exit temperature (T48) [C]                                   -4.171919e-02
# GT Compressor inlet air temperature (T1) [C]                                      NaN
# GT Compressor outlet air temperature (T2) [C]                           -4.909594e-02
# HP Turbine exit pressure (P48) [bar]                                     6.266350e-03
# GT Compressor inlet air pressure (P1) [bar]                              8.732834e-13
# GT Compressor outlet air pressure (P2) [bar]                             6.488394e-03
# Gas Turbine exhaust gas pressure (Pexh) [bar]                            3.339688e-02
# Turbine Injecton Control (TIC) [%]                                      -3.414874e-02
# Fuel flow (mf) [kg/s]                                                   -1.583545e-02
# GT Compressor decay state coefficient.                                   1.000000e+00
# GT Turbine decay state coefficient.                                     -9.849039e-04
#
#                                                GT Turbine decay state coefficient.
# Unnamed: 0                                                            4.072109e-03
# Lever position (lp) [ ]                                              -1.044850e-03
# Ship speed (v) [knots]                                               -1.008008e-03
# Gas Turbine shaft torque (GTT) [kN m]                                -5.327690e-04
# Gas Turbine rate of revolutions (GTn) [rpm]                          -6.767443e-04
# Gas Generator rate of revolutions (GGn) [rpm]                         8.703413e-03
# Starboard Propeller Torque (Ts) [kN]                                 -6.686727e-04
# Port Propeller Torque (Tp) [kN]                                      -6.686727e-04
# HP Turbine exit temperature (T48) [C]                                -3.990061e-02
# GT Compressor inlet air temperature (T1) [C]                                   NaN
# GT Compressor outlet air temperature (T2) [C]                        -1.806027e-02
# HP Turbine exit pressure (P48) [bar]                                 -3.527565e-03
# GT Compressor inlet air pressure (P1) [bar]                           2.074981e-12
# GT Compressor outlet air pressure (P2) [bar]                         -1.917078e-02
# Gas Turbine exhaust gas pressure (Pexh) [bar]                         1.126419e-02
# Turbine Injecton Control (TIC) [%]                                   -1.916872e-02
# Fuel flow (mf) [kg/s]                                                -1.816774e-02
# GT Compressor decay state coefficient.                               -9.849039e-04
# GT Turbine decay state coefficient.                                   1.000000e+00

# %%
sns.heatmap(df.corr())

# %%
df.shape
# Out:
# (10000, 19)

# %%
x=df.iloc[:,2:]
y=df.iloc[:,1]

# %%
x.shape
# Out:
# (10000, 17)

# %%
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [1.36257245e-01 6.62576776e-02 1.52966500e-01 7.56660315e-02
#  8.37119852e-02 8.57481264e-02 2.42864553e-02 0.00000000e+00
#  5.36438098e-02 6.66881235e-02 0.00000000e+00 7.15594162e-02
#  1.15534155e-01 1.00768042e-02 5.76036707e-02 3.45797057e-14
#  1.65689656e-14]

# %%
feat_importances=pd.Series(model.feature_importances_, index=x.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (8000, 17)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_random=RandomForestRegressor()

# %%
n_estimators=[int(x) for x in np.linspace(start=100, stop=1200, num=12)]
max_features=['auto', 'sqrt']
max_depth=[int(x) for x in np.linspace(5,30, num=6)]
min_samples_split=[2,5,10,15,100]
min_samples_leaf=[1,2,5,10]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_grid={'n_estimators': n_estimators,
             'max_features': max_features,
             'max_depth':max_depth,
             'min_samples_split': min_samples_split,
             'min_samples_leaf': min_samples_leaf
             }
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf=RandomForestRegressor()

# %%
rf_random=RandomizedSearchCV(estimator =rf, param_distributions= random_grid, scoring='neg_mean_squared_error', n_iter=10, cv=5,verbose=2, random_state=42, n_jobs=1)

# %%
rf_random.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   3.7s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.6s remaining:    0.0s
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   3.7s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   3.7s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   3.7s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   3.6s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   4.5s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   4.3s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   4.5s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   4.7s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   5.2s
# [CV] n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=   4.2s
# [CV] n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=   4.2s
# [CV] n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=   5.9s
# [CV] n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=   4.0s
# [CV] n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=   4.0s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   5.3s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   5.1s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   5.2s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   5.0s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   5.1s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20, total=   8.8s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20, total=   9.1s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20, total=   9.0s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20, total=   8.7s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=10, max_features=auto, max_depth=20, total=   8.7s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   4.0s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   4.0s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   4.1s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   4.0s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   4.1s
# [CV] n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   4.2s
# [CV] n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   4.2s
# [CV] n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   4.2s
# [CV] n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   4.3s
# [CV] n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   4.3s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.2s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.2s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.2s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.2s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.3s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   2.7s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   2.7s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   2.7s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   2.7s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   2.7s
# [CV] n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20, total=   9.1s
# [CV] n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20, total=   8.9s
# [CV] n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20, total=   9.1s
# [CV] n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20, total=   8.7s
# [CV] n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=20, total=   9.4s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  4.0min finished
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
predictions=rf_random.predict(x_test)

# %%
predictions
# Out:
# array([7.148, 6.175, 7.148, ..., 8.206, 7.148, 8.206])

# %%
sns.distplot(y_test-predictions)

# %%
plt.scatter(y_test,predictions)

# %%
import pickle
file=open('propulsion_data.pkl', 'wb')
pickle.dump(rf_random, file)
